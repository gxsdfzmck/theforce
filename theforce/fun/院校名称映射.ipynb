# %% [markdown]
# # 使用python3运行，解决encoding的问题

# %%
import ipywidgets as widgets
from IPython.display import display

from config import new_mysql_connect
from link_name import IDNameLinker, IDNameSelector

db = new_mysql_connect()
cursor = db.cursor()

# %% [markdown]
# # 准备原始数据

# %%
#cursor.execute('select distinct uname from allspark_dev.uniscore_16 where uid is null and uname not in (select verbose_name from datamodel.university_name_mapping)')
cursor.execute('select distinct uname from allspark_dev.uniscore_16 where uid is null')
results = cursor.fetchall() 
raw_datas = [ row[0] for row in results ]
raw_count = len(raw_datas)

# %% [markdown]
# # 准备标准数据

# %%
uname_selector = IDNameSelector('sdb.sdb_university', 'id', 'name')
names = uname_selector.get_all()

# %%
import re
class NameLinker(object):

    def __init__(self, standards):
        self._db = standards
        self._name_patterns = []
        self._name_patterns.append(re.compile('([^()]+)\(引进[^()]+课程\)'))
        self._name_patterns.append(re.compile('([^()]+)\([^()]+专业\)'))
        self._name_patterns.append(re.compile('([^()]+)\(与[^()]+合办\)'))
        self._name_patterns.append(re.compile('([^()]+)\(与[^()]+联办\)'))
        self._name_patterns.append(re.compile('([^()]+)\([^()]*就读[^()]*\)'))
        self._name_patterns.append(re.compile('([^()]+)\([^()]*办学[^()]*\)'))
        
        self._split_pattern = re.compile('([^()]+)\(原([^()]+)\)')

    def get(self, name):
        result = self.get_equal_value(name)
        if result:
            return result    
        for new_name in self.correct_name(name):
            tmp = self.get_equal_value(new_name)
            if tmp:
                if result and result['id'] != tmp['id']:
                    return
                result = tmp
        return result
        
    def get_equal_value(self, name):
        for key, value in self._db.items():
            if value == name:
                return {'id': key, 'name': value}

    def correct_name(self, name):
        names = set()     
        # 第一步：标准化名称
        name = name.replace('（', '(').replace('）', ')')
        name = name.replace('(较高收费)', '').replace('(较高学费)', '')
        name = name.replace('(中外合作办学)', '').replace('(对外合作办学)', '')
        name = name.replace('(仅招少数民族)', '')
        name = name.replace('(护理)', '')
        
        # 补齐（）
        if name.count('(') - name.count(')') == 1:
            name = name + ')'
        
        # 正则修正
        for pattern in self._name_patterns:        
            matches = pattern.match(name)
            if matches:
                name = matches.group(1)
        names.add(name)
        
        # 第二步：拆出可能的名称
        matches = self._split_pattern.match(name)
        if matches:
            names.add(matches.group(1))
            names.add(matches.group(2))
        
        return names

linker = NameLinker(names)

# %% [markdown]
# # 开始执行possible_values替换

# %%
results = []
for name in raw_datas:
    value = linker.get(name)
    results.append({'name': name, 'value':value})
results_no = [ item for item in results if item['value'] is None ]
results_ok = [ item for item in results if item['value'] is not None ]

print('正常匹配：', len(results_ok))
print('没有匹配：', len(results_no))
# Out:
# 正常匹配： 0
# 没有匹配： 326

# %%
def _fn(e):
    print('共有', raw_count, '个待映射的名称')
    for i, name in enumerate(raw_datas):
        print('[{}/{}]: {}'.format(i+1, raw_count, name))
btn = widgets.Button(description='显示待处理的院校名称')
btn.on_click(_fn)
display(btn)

def _fn(e):
    print('共有', len(results_ok), '个待映射的名称')
    for i, name in enumerate(results_ok):
        item = results_ok[i]
        print('[{}/{}]: {} -> {}'.format(i+1, len(results_ok), item['name'], item['value']))
btn = widgets.Button(description='显示完成处理的院校名称')
btn.on_click(_fn)
display(btn)

def _fn(e):
    print('共有', len(results_no), '个待映射的名称')
    for i, name in enumerate(results_no):
        item = results_no[i]
        print('[{}/{}]: {}'.format(i+1, len(results_no), item['name']))
btn = widgets.Button(description='显示未完成处理的院校名称')
btn.on_click(_fn)
display(btn)

def _fn(e):
    print('更新映射内容到数据库中')
    for i, name in enumerate(results_ok):
        item = results_ok[i]
        try:
            cursor.execute('insert into datamodel.university_name_mapping(verbose_name, standard_name, standard_id) values(%s, %s, %s)', [item['name'], item['value']['name'], item['value']['id']])
            print('[{}/{}]: {} -> {}'.format(i+1, len(results_ok), item['name'], item['value']))
        except:
            continue
    print('结束更新映射内容到数据库中')
btn = widgets.Button(description='更新映射内容到数据库中')
btn.on_click(_fn)
display(btn)

def _fn(e):
    print('关闭数据库连接')
    cursor.close()
    db.close()
btn = widgets.Button(description='关闭数据库连接')
btn.on_click(_fn)
display(btn)
# Out:
# 共有 326 个待映射的名称
# [1/326]: 上海体育职业学院
# [2/326]: 上海兴韦信息技术职业学院
# [3/326]: 上海兴韦信息技术职业学院(原上海托普信息技术职业学院)
# [4/326]: 上海医疗器械高等专科学校
# [5/326]: 上海对外贸易学院
# [6/326]: 上海工商外国语职业学院
# [7/326]: 上海工商职业技术学院(原上海新侨职业技术学院)
# [8/326]: 上海欧华职业技术学院
# [9/326]: 东北石油大学华瑞学院
# [10/326]: 东北财经大学津桥商学院
# [11/326]: 中原工学院(软件类)
# [12/326]: 中国地质大学江城学院
# [13/326]: 中国矿业大学
# [14/326]: 中国矿业大学(较高收费)
# [15/326]: 云南热带作物职业学院
# [16/326]: 云南经济管理职业学院
# [17/326]: 信阳农业高等专科学校
# [18/326]: 信阳农业高等专科学校(中外合作办学)
# [19/326]: 信阳农业高等专科学校(对外合作办学)
# [20/326]: 信阳师范学院与信阳农业高等专科学校联办
# [21/326]: 健雄职业技术学院
# [22/326]: 兰州工业高等专科学校
# [23/326]: 内蒙古医学院
# [24/326]: 内蒙古财经学院
# [25/326]: 北京交通大学(威海校区)(较高收费)
# [26/326]: 北京化工大学北方学院
# [27/326]: 北京吉利大学
# [28/326]: 北京建筑工程学院
# [29/326]: 北京新圆明职业学院
# [30/326]: 北京航空航天大学北海学院
# [31/326]: 北海艺术设计职业学院
# [32/326]: 十堰职业技术学院
# [33/326]: 华中科技大学文华学院
# [34/326]: 华北水利水电大学(中外合作办学)各专业入学地点以录取通知书为准
# [35/326]: 华北水利水电大学与嵩山少林武术职业学院联办
# [36/326]: 华北水利水电大学与嵩山少林武术职业学院联办(前两年就读在嵩山)
# [37/326]: 华北水利水电大学与嵩山少林武术职业学院联办(前两年就读嵩山)
# [38/326]: 华北水利水电学院
# [39/326]: 华北水利水电学院(中外合作办学)
# [40/326]: 华北水利水电学院(办学地点在外国语学院)
# [41/326]: 华北水利水电学院(办学地点在河南省郑州水利学校)
# [42/326]: 华北水利水电学院(办学地点：外国语学院)
# [43/326]: 华北水利水电学院(对外合作办学)
# [44/326]: 华北水利水电学院与嵩山少林武术职业学院联办
# [45/326]: 华北理工大学(原河北理工大学与华北煤炭医学院合并组建)
# [46/326]: 华北理工大学冀唐学院
# [47/326]: 华北理工大学轻工学院
# [48/326]: 华南师范大学增城学院
# [49/326]: 华南理工大学广州汽车学院
# [50/326]: 南京人口管理干部学院
# [51/326]: 南京化工职业技术学院
# [52/326]: 南海东软信息技术职业学院
# [53/326]: 南通农业职业技术学院
# [54/326]: 南通纺织职业技术学院
# [55/326]: 南阳理工学院与南阳医学高等专科学校联办
# [56/326]: 南阳理工学院与南阳医学高等专科学校联办(就读在南阳医专)
# [57/326]: 南阳理工学院与南阳医学高等专科学校联办就读在南阳医专
# [58/326]: 厦门南洋职业学院(翔安校区)
# [59/326]: 吉安职业技术学院
# [60/326]: 吉林农业大学发展学院
# [61/326]: 吉林农业工程职业技术学院
# [62/326]: 吉林建筑工程学院
# [63/326]: 吉林建筑工程学院城建学院
# [64/326]: 吉林财经大学信息经济学院
# [65/326]: 周口职业技术学院(中外合作办学)与加拿大剑智文理学院合作办学
# [66/326]: 咸宁学院
# [67/326]: 哈尔滨华夏计算机职业技术学院
# [68/326]: 哈尔滨商业大学广厦学院
# [69/326]: 哈尔滨德强商务学院
# [70/326]: 哈尔滨现代公共关系职业学院
# [71/326]: 哈尔滨理工大学远东学院
# [72/326]: 商丘学院应用科技学院(办学地点在开封)
# [73/326]: 商丘学院应用科技学院(办学地点在开封市)
# [74/326]: 商丘师范学院(专升本)
# [75/326]: 四川外语学院
# [76/326]: 四川外语学院成都学院
# [77/326]: 四川外语学院重庆南方翻译学院
# [78/326]: 四川师范大学文理学院
# [79/326]: 四川烹饪高等专科学校
# [80/326]: 四川警安职业学院
# [81/326]: 四川音乐学院绵阳艺术学院
# [82/326]: 复旦大学医学院
# [83/326]: 大连商务职业学院
# [84/326]: 大连外国语学院
# [85/326]: 大连民族学院已经更名为大连民族大学
# [86/326]: 大连理工大学(盘锦校区)
# [87/326]: 大连翻译职业学院
# [88/326]: 天津商务职业学院原天津对外经济贸易职业学院
# [89/326]: 天津城市建设学院
# [90/326]: 天津开发区职业技术学院
# [91/326]: 太原大学
# [92/326]: 太原电力高等专科学校
# [93/326]: 孝感学院
# [94/326]: 孝感学院新技术学院
# [95/326]: 宁波天一职业技术学院
# [96/326]: 安徽中医学院
# [97/326]: 安徽广播影视职业技术学院
# [98/326]: 安徽建筑工业学院
# [99/326]: 安徽长江职业学院
# [100/326]: 宜春幼儿师范高等专科学校
# [101/326]: 山东万杰医学院
# [102/326]: 山东丝绸纺织职业学院
# [103/326]: 山东华宇职业技术学院
# [104/326]: 山东大王职业学院
# [105/326]: 山东杏林科技职业学院
# [106/326]: 山东经济学院
# [107/326]: 山东经济学院燕山学院
# [108/326]: 山东职业学院原济南铁道职业技术学院
# [109/326]: 山东胜利职业学院
# [110/326]: 山东财政学院
# [111/326]: 山东轻工业学院
# [112/326]: 山西兴华职业学院
# [113/326]: 山西生物应用职业技术学院
# [114/326]: 山西财政税务专科学校
# [115/326]: 巢湖职业技术学院
# [116/326]: 平顶山文化艺术职业学院
# [117/326]: 广东商学院
# [118/326]: 广东商学院华商学院
# [119/326]: 广东江门艺华旅游职业学院
# [120/326]: 广东省外语艺术职业学院
# [121/326]: 广东纺织职业技术学院
# [122/326]: 广州医学院
# [123/326]: 广州工商职业技术学院
# [124/326]: 广播电影电视管理干部学院
# [125/326]: 广西中医学院赛恩斯新医药学院
# [126/326]: 广西工学院
# [127/326]: 广西工学院鹿山学院
# [128/326]: 开封教育学院
# [129/326]: 徐州师范大学
# [130/326]: 怀化医学高等专科学校
# [131/326]: 成都理工大学广播影视学院
# [132/326]: 成都电子机械高等专科学校
# [133/326]: 扬州中瑞酒店职业学院
# [134/326]: 扬州环境资源职业技术学院
# [135/326]: 新乡医学院(中外课程合作)
# [136/326]: 新乡医学院与漯河医学高等专科学校合作办学(就读漯河医专)
# [137/326]: 新疆工业高等专科学校
# [138/326]: 新疆机电职业技术学院
# [139/326]: 昆明医学院
# [140/326]: 昆明医学院海源学院
# [141/326]: 昭通师范高等专科学校
# [142/326]: 景德镇高等专科学校
# [143/326]: 曲阜师范大学杏坛学院
# [144/326]: 柳州医学高等专科学校
# [145/326]: 桂林工学院博文管理学院
# [146/326]: 桂林航天工业高等专科学校
# [147/326]: 武汉商业服务学院
# [148/326]: 武汉工业学院
# [149/326]: 武汉工业学院工商学院
# [150/326]: 武汉语言文化职业学院
# [151/326]: 武汉长江工商学院
# [152/326]: 毕节学院
# [153/326]: 民办万博科技职业学院万博科技职业学院
# [154/326]: 民办四川天一学院绵竹校区
# [155/326]: 江苏技术师范学院
# [156/326]: 江苏畜牧兽医职业技术学院
# [157/326]: 江苏科技大学南徐学院
# [158/326]: 江苏食品职业技术学院
# [159/326]: 江西中医学院
# [160/326]: 江西中医学院(较高收费)
# [161/326]: 江西中医学院科技学院
# [162/326]: 江西医学院上饶分院
# [163/326]: 江西城市职业学院
# [164/326]: 江西太阳能科技职业学院
# [165/326]: 江西护理职业技术学院
# [166/326]: 江西新闻出版职业技术学院
# [167/326]: 江西渝州科技职业学院
# [168/326]: 江西科技师范学院
# [169/326]: 江西科技师范学院理工学院
# [170/326]: 江西管理职业学院
# [171/326]: 江西蓝天学院
# [172/326]: 沈阳农业大学科学技术学院
# [173/326]: 沈阳大学科技工程学院
# [174/326]: 沈阳工学院(原沈阳理工大学应用技术学院和沈阳农业大学科学技术(民办))
# [175/326]: 沈阳建筑大学城市建设学院
# [176/326]: 沈阳理工大学应用技术学院
# [177/326]: 沈阳航空职业技术学院
# [178/326]: 沈阳航空航天大学北方科技学院
# [179/326]: 河南中医学院与嵩山少林武术职业学院联合办学
# [180/326]: 河南中医学院与嵩山少林武术职业学院联合办学(前两年就读嵩山)
# [181/326]: 河南中医学院与嵩山少林武术职业学院联合办学前两年就读嵩山
# [182/326]: 河南卫生职工学院
# [183/326]: 河南商业高等专科学校
# [184/326]: 河南商业高等专科学校(中外合作办学)
# [185/326]: 河南大学(与濮阳市联办濮阳工学院)就读地点：濮阳市
# [186/326]: 河南大学(人民武装学院)
# [187/326]: 河南大学(国际通识课程)(就读在欧亚国际学院)
# [188/326]: 河南大学(国际通识课程)(较高收费)
# [189/326]: 河南大学(郑州校区)
# [190/326]: 河南大学与开封大学联合办学
# [191/326]: 河南大学与开封大学联合办学(就读地址：开封大学)
# [192/326]: 河南大学国际教育学院(中外合作办学)
# [193/326]: 河南工业大学(学地点在河南辅读中等职业学校)
# [194/326]: 河南师范大学与河南教育学院联合办学
# [195/326]: 河南师范大学与河南教育学院联合办学(就读在河南教育学院)
# [196/326]: 河南师范大学与河南教育学院联合办学就读在河南教育学院
# [197/326]: 河南师范大学与河南机电高等专科学校联合办学
# [198/326]: 河南师范大学与河南机电高等专科学校联合办学(就读在河南机专)
# [199/326]: 河南师范大学与河南机电高等专科学校联合办学(就读新乡平原路699号)
# [200/326]: 河南师范大学与河南机电高等专科学校联合办学就读在河南机专
# [201/326]: 河南师范大学与焦作师范高等专科学校联合办学
# [202/326]: 河南师范大学与焦作师范高等专科学校联合办学(就读在焦作师专)
# [203/326]: 河南师范大学与焦作师范高等专科学校联合办学就读在焦作师专
# [204/326]: 河南机电高等专科学校(软件学院)
# [205/326]: 河南牧业经济学院(中外合作)(就读英才校区)
# [206/326]: 河南牧业经济学院(中外合作)(英才校区)
# [207/326]: 河南牧业经济学院(软件类)(就读英才校区)
# [208/326]: 河南牧业经济学院(软件类)(英才校区)
# [209/326]: 河南理工大学(与鹤壁市政府联办工程技术学院)(就读在鹤壁)
# [210/326]: 河南理工大学(学地点在焦作市建设西路55号)
# [211/326]: 河南理工大学万方科技学院(富士康专班)
# [212/326]: 河南理工大学万方科技学院(富士康专班郑州校区)
# [213/326]: 河南经贸职业学院(中外合作办学)就读地点：郑州市白杨路6号
# [214/326]: 河南艺术职业学院(文化路校区,原中原工学院广播影视职业学院)
# [215/326]: 河南财经政法大学(与俄罗斯人民友谊大学本科课程合作项目)
# [216/326]: 河南财经政法大学(国家留学基金委国际本科学术互认课程)
# [217/326]: 河南财经政法大学与河南检察职业学院联办
# [218/326]: 河南财经政法大学与河南检察职业学院联办(就读在河南检察职业学院)
# [219/326]: 河南财经政法大学与河南检察职业学院联办就读在河南检察职业学院
# [220/326]: 河南财经政法大学成功学院
# [221/326]: 河套大学
# [222/326]: 泉州信息职业技术学院
# [223/326]: 泉州华光摄影艺术职业学院
# [224/326]: 泉州泰山航海职业学院
# [225/326]: 泰州师范高等专科学校
# [226/326]: 浙江农林大学天目学院
# [227/326]: 浙江大学医学院
# [228/326]: 浙江水利水电专科学校
# [229/326]: 浙江财经学院
# [230/326]: 浙江财经学院东方学院
# [231/326]: 海南大学三亚学院
# [232/326]: 渤海大学文理学院
# [233/326]: 温州医学院
# [234/326]: 温州医学院仁济学院
# [235/326]: 湖南信息科学职业学院
# [236/326]: 湖南同德职业学院
# [237/326]: 湖南科技经贸职业学院
# [238/326]: 湛江师范学院
# [239/326]: 湛江现代科技职业学院
# [240/326]: 漳州天福茶职业技术学院
# [241/326]: 漳州师范学院
# [242/326]: 潍坊工程职业学院原潍坊教育学院
# [243/326]: 甘肃联合大学
# [244/326]: 盐城纺织职业技术学院
# [245/326]: 石家庄城市职业学院(原石家庄法商职业学院 )
# [246/326]: 石家庄城市职业学院(原石家庄法商职业学院)
# [247/326]: 石家庄外事职业学院
# [248/326]: 石家庄外国语职业学院
# [249/326]: 石家庄外语翻译职业学院
# [250/326]: 石家庄经济学院北校区
# [251/326]: 石家庄计算机职业学院
# [252/326]: 福建交通职业技术学院
# [253/326]: 肇庆工商职业技术学院
# [254/326]: 芜湖信息技术职业学院
# [255/326]: 苏州职业大学
# [256/326]: 萍乡高等专科学校
# [257/326]: 衡阳财经工业职业技术学院
# [258/326]: 襄樊学院
# [259/326]: 襄樊学院理工学院
# [260/326]: 襄樊职业技术学院
# [261/326]: 西南大学育才学院
# [262/326]: 西安三资职业学院
# [263/326]: 西安电子科技大学长安学院
# [264/326]: 西安科技商贸职业学院
# [265/326]: 西安航空技术高等专科学校
# [266/326]: 西安邮电学院
# [267/326]: 贵州亚泰职业学院
# [268/326]: 贵州医科大学神奇民族医药学院
# [269/326]: 贵州商学院
# [270/326]: 贵州民族学院人文科技学院
# [271/326]: 贵州财经学院
# [272/326]: 贵州财经学院商务学院
# [273/326]: 贵港职业学院
# [274/326]: 辽宁交通高等专科学校
# [275/326]: 辽宁信息职业技术学院
# [276/326]: 辽宁卫生职业技术学院
# [277/326]: 辽宁建筑职业技术学院
# [278/326]: 辽宁石油化工大学顺华能源学院
# [279/326]: 辽宁科技大学信息技术学院
# [280/326]: 辽宁美术职业学院
# [281/326]: 辽宁警官高等专科学校
# [282/326]: 邕江大学
# [283/326]: 邕江大学(已更名为南宁学院)
# [284/326]: 郑州交通职业学院
# [285/326]: 郑州华信学院
# [286/326]: 郑州华信学院(中外合作办学)
# [287/326]: 郑州华信学院(对外合作办学)
# [288/326]: 郑州大学(软件职业技术学院)
# [289/326]: 郑州大学与嵩山少林武术职业学院联办(前两年就读在嵩少)
# [290/326]: 郑州大学与嵩山少林武术职业学院联办(前两年就读在嵩山)
# [291/326]: 郑州大学与嵩山少林武术职业学院联办前两年在嵩山
# [292/326]: 郑州大学与嵩山少林武术职业学院联合办学
# [293/326]: 郑州大学与河南财政税务高专联合办学（就读在财专）
# [294/326]: 郑州大学与河南财政税务高等专科联合办学(就读在财专)
# [295/326]: 郑州大学体育学院
# [296/326]: 郑州大学西亚斯国际学院
# [297/326]: 郑州大学西亚斯国际学院(与美国堪萨斯州富特海斯州立大学合办)
# [298/326]: 郑州大学西亚斯国际学院与美国堪萨斯州富特海斯州立大学合办
# [299/326]: 郑州师范学院与中原文化艺术学院(筹)合办
# [300/326]: 郑州师范学院与中原文化艺术学院(筹)合办(就读地：郑开大道19号)
# [301/326]: 郑州牧业工程高等专科学校
# [302/326]: 郑州牧业工程高等专科学校(对外合作办学)
# [303/326]: 郑州电子信息职业技术学院(西校区)
# [304/326]: 郑州经贸职业学院
# [305/326]: 郑州轻工业学院分别就读在郑州东风路5号、郑州高新区科学大道166号
# [306/326]: 郑州轻工业学院易斯顿美术学院
# [307/326]: 重庆幼儿师范高等专科学校重庆幼儿师范高等专科学校
# [308/326]: 重庆正大软件职业技术学院
# [309/326]: 银川科技职业学院
# [310/326]: 长春大学光华学院
# [311/326]: 长春师范学院
# [312/326]: 长春师范学院(较高学费)
# [313/326]: 长沙师范学校
# [314/326]: 长沙通信职业技术学院
# [315/326]: 阜阳师范学院
# [316/326]: 阳泉职业技术学院
# [317/326]: 青岛恒星职业技术学院
# [318/326]: 青岛飞洋职业技术学院
# [319/326]: 鸡西大学
# [320/326]: 黄河科技学院(应用技术学院)(办学地点在济源市)
# [321/326]: 黄河科技学院(应用技术学院)(各专业办学地点在济源市)
# [322/326]: 黄石理工学院
# [323/326]: 黄石职业技术学院
# [324/326]: 黑龙江工商职业技术学院
# [325/326]: 黑龙江科技学院
# [326/326]: 黑龙江科技职业学院
